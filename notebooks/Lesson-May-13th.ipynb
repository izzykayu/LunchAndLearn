# %% [markdown]
# import glob

# %%
import glob
import pandas as pd
pd.set_option('max_colwidth', 100)

files_ = glob.glob('../data/bdcase/*')

print(len(files_))
print(files_)



df2016 = pd.read_csv(files_[0])
(df2016[['No EVM Explanation', 'Program Code FPI', 'CIO Evaluation Comments','Bureau Name']]
['Bureau Name'].value_counts())
# Out:
# ['../data/bdcase/BusinessCase-DHS-2016.csv', '../data/bdcase/Business_Case-DHS-2017.csv', '../data/bdcase/Business_Case-DHS-2019.csv', '../data/bdcase/Business_Case-DHS-2018.csv', '../data/bdcase/Business_Case-DHS-2020.csv', '../data/bdcase/Business_Case-DHS-2021.csv', '../data/bdcase/Business_Case-DHS-2022.csv']
# U.S. Customs and Border Protection              18
# United States Coast Guard                       14
# Transportation Security Administration          10
# National Protection and Programs Directorate     9
# Department of Homeland Security                  8
# Citizenship and Immigration Services             8
# Immigration and Customs Enforcement              7
# Federal Emergency Management Agency              7
# Departmental Management and Operations           5
# United States Secret Service                     3
# Name: Bureau Name, dtype: int64

# %%
def craete_df(file, write=True):
    df2022 = pd.read_csv(file)
    df2022 = df2022.rename(columns={col: col.replace(' ', '') for col in list(df2022.columns)})


    id_cols = [col for col in df2022.columns if col.lower().endswith('id') or col.lower().endswith('code')] + ['UniqueInvestmentIdentifier',]

    
    df2022[id_cols] = df2022[id_cols].applymap(str)
    col_d = {}
    
    date_cols = [col for col in df2022.columns if 'date' in col.lower() ] + ['BudgetYear']
    num_cols = ['FundingPY1andPrior($M)', 'FundingPY($M)', 'FundingCY($M)',
       'FundingBY($M)', 'InvestmentStartYear', 'InvestmentEndYear','InvestmentYears', 'Evaluation(byAgencyCIO)', 'ConsecutiveMonthswithRedCIOEval',
       'NumberofchangestoBaseline']
    
    df2022['InvestmentYears'] = (df2022['InvestmentEndYear'] -  df2022['InvestmentStartYear'])

    df2022[[col for col in df2022.columns if col not in id_cols + date_cols + num_cols]]

    text_cols = ['AgencyStrategicObjectives/AgencyPriorityGoals',  'PaperworkReductionActOMBControlNumber(s)', 'ROIDescription',  'ExplanationofChangetoPYorCYFunding','CIOEvaluationComments', 'PMQualifications']
    exclude_cols = ['DataFreshness', 'fileName', 'PMName', 'AgencyName', 'DataFreshness','BureauCode', 'InvestmentType','InfrastructureManagementCategory', ]
    
    cat_cols = ['BureauName', 'InvestmentTitle', 'InvestmentSharedService', 'PlannedSharedService', 'AnalysisConclusion', '']
    col_d['category'] = cat_cols
    col_d['numeric'] = num_cols
    col_d['dates'] = date_cols
    col_d['ids'] = id_cols
    col_d['text'] = text_cols
    col_d['exclude'] = exclude_cols
    
    print(len(id_cols + date_cols + num_cols + cat_cols + text_cols))
    print(df2022.shape)
    df2022['fileName'] = file.split('/')[-1]
    print(file)
    return (
        df2022, col_d #[[col for col in df2022.columns if col not in id_cols + date_cols + num_cols + text_cols+ exclude_cols]]
    )

df1, col_d = craete_df(files_[-1])


def Make_binaryflag(df, columns=[]):
    for col in columns:
        df[col+'Flag'] = df[col].map(lambda x: False if str(x).lower() == 'nan' else True)
    return df


def count_string(df, values_list=[('AgencyStrategicObjectives/AgencyPriorityGoals', ' - '),('PaperworkReductionActOMBControlNumber(s)','|')]):
    for values_ in values_list:
        df[values_[0] + 'Count'] = df[values_[0]].map(lambda x: None if pd.isnull(x) else  len(x.split(values_[-1]))).fillna(0)
    
    return df




# Make_binaryflag(df1.drop(columns=col_d['exclude'])
#                )
# count_string(df1.drop(columns=col_d['exclude'] + col_d['ids'])
#             )[col_d['text'] + ['BureauName','ProgramCodeFPI']]
df1[['PIVEnabled', 'PublicAPI']].applymap(lambda x: 1 if x.lower() == 'yes' else 0)
df1.to_dict('records')[3]

print(df1.columns)

binaryflagcols = [ 'SharedService', 'PIVEnabled', 'PublicAPI',
       'OpenDataEvaluation-SystemDesign',
       'OpenDataEvaluation-EnterpriseDataInventory',
       'OpenDataEvaluation-OutputsMeetM-13-13',
       'OpenDataEvaluation-SchemaandDictionaryDocumentedandShared',
       'OpenDataEvaluation-NotApplicable-NotNeworModernizing','OpenDataEvaluation-NotYetValidatedbyCIO',]
# Out:
# 40
# (89, 50)
# ../data/bdcase/BusinessCase-DHS-2016.csv
# Index(['UniqueInvestmentIdentifier', 'BusinessCaseID', 'AgencyCode',
#        'AgencyName', 'BureauCode', 'BureauName',
#        'InvestmentTitle(ITPortfolio)', 'BriefSummary', 'ProgramCodeFPI',
#        'EAandInnovation', 'ROIDescription', 'AccomplishmentsPY',
#        'AccomplishmentsCYBY', 'SharedService', 'PIVEnabled', 'PublicAPI',
#        'OpenDataEvaluation-SystemDesign',
#        'OpenDataEvaluation-EnterpriseDataInventory',
#        'OpenDataEvaluation-OutputsMeetM-13-13',
#        'OpenDataEvaluation-SchemaandDictionaryDocumentedandShared',
#        'OpenDataEvaluation-NotApplicable-NotNeworModernizing',
#        'OpenDataEvaluation-NotApplicable-NotAppropriate(Comment)',
#        'OpenDataEvaluation-NotYetValidatedbyCIO', 'FundingPY1andPrior($M)',
#        'FundingPY($M)', 'FundingCY($M)', 'FundingBY($M)',
#        'InvestmentStartYear', 'InvestmentEndYear',
#        'ExplanationofChangetoPYorCYFunding', 'NoEVMExplanation',
#        'Evaluation(byAgencyCIO)', 'CIOEvaluationComments',
#        'CIOEvaluationColor', 'DateofLastUpdatetoCIOEvaluation',
#        'DateofLastChangetoCIOEvaluation', 'NumberofchangestoBaseline',
#        'DateofLastBaseline', 'DateofLastChangetoActivities',
#        'DateofLastUpdatetoActivities', 'DataFreshness',
#        'DateofLastChangetoContracts', 'DateofLastChangetoPerformanceMetrics',
#        'DateofLastUpdatetoPerformanceMetricActuals', 'DateofLastTechStat',
#        'BudgetYear', 'DateInvestmentFirstSubmitted',
#        'DateofLastInvestmentDetailUpdate', 'InvestmentAutoSubmissionDate',
#        'InvestmentYears', 'fileName'],
#       dtype='object')

# %%
def make_binary(df, columns=[]):
    for col, val in columns:
        df[col + 'BinaryFlag'] =(df[col].map(lambda x: -1 if pd.isnull(x) else x)
        .map(lambda x: 1 if str(x).lower()==val else 0)
                                )
    return df

#make_binary(df1, columns=[(col, 'yes') for col in binaryflagcols])
num_cols = ['FundingPY1andPrior($M)', 'FundingPY($M)', 'FundingCY($M)',
       'FundingBY($M)', 'InvestmentStartYear', 'InvestmentEndYear',
       'Evaluation(byAgencyCIO)', 'NumberofchangestoBaseline', 'BudgetYear',
       'InvestmentYears']
codes = ['AgencyCode', 'BureauCode', 'BusinessCaseID', 'fileName',]
category_cols = ['CIOEvaluationColor', 'DataFreshness']
exclude_cols

date_cols = [col for col in df1.columns if 'date' in col.lower()]
print(dfe['BureauName'].value_counts())

dfe = df1[[col for col in df1.columns if col not in ['UniqueInvestmentIdentifier'] +id_cols + exclude_cols+ binaryflagcols + date_cols + num_cols]]
# Out:
# U.S. Customs and Border Protection              18
# United States Coast Guard                       14
# Transportation Security Administration          10
# National Protection and Programs Directorate     9
# Department of Homeland Security                  8
# Citizenship and Immigration Services             8
# Immigration and Customs Enforcement              7
# Federal Emergency Management Agency              7
# Departmental Management and Operations           5
# United States Secret Service                     3
# Name: BureauName, dtype: int64

# %%
web = spacy.load('en_core_web_lg')
# Out:
# /Users/isabelkayumetzger/opt/miniconda3/envs/llenv/lib/python3.8/site-packages/spacy/util.py:837: UserWarning: [W095] Model 'en_core_web_lg' (3.2.0) was trained with spaCy v3.2 and may not be 100% compatible with the current version (3.3.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
dfes = dfe[dfe['BureauName'].map(lambda x: True if x in ['United States Coast Guard', 'Immigration and Customs Enforcement',] else False) ]
                                 
cioevalcomments = dfes['NoEVMExplanation'].map(lambda x: x.replace('\n', ' ')).tolist()
docs = list(web.pipe(cioevalcomments))
from spacy import displacy


from IPython.core.display import display, HTML
count = 0
investmentnames =dfes['InvestmentTitle(ITPortfolio)'].map(str).tolist()
for i, doc in enumerate(docs):
    print('\n\n' + investmentnames[i] + ':')
    
    html = displacy.render(doc.sents, style="ent")
    display(HTML(html))
    print('\n\n')
# Out:
# ICE - Detention and Removal Operations Modernization (DROM):
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DROM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  contract that does not require the use of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> Because
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Applications Operations &amp; Maintenance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     O&amp;M
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) (HSCETC-13-F-00044) contract does not meet the dollar threshold for the use of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> The contract type is fixed firm price.</div></span>
# ICE - IT Infrastructure:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">There are
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  IAAs and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  contract currently awarded by this investment over the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $20M
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  threshold required by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DHS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  monitoring. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">These IAAs/contracts are for Engineering and IT Maintenance Support Services, and thus, not subject to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  reporting. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Any future IAAs/contracts above the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $20M
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  threshold will be reviewed to determine if
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is required.</div></span>
# ICE - Federal Financial Management System (FFMS):
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     N/A
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  because the contract is
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     O&amp;M
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , however, there is cost, deliverable, and performance monitoring under the terms and conditions of the contracts / task orders which are in place and being planned for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FFMS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Quarterly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  quality assurance reports are also done
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quarterly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> The most recent has been attached to this Exhibit
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     300
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  on the release tab.</div></span>
# ICE - Electronic Health Record (EHR) System:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is not required for Firm Fixed Price contracts.</div></span>
# ICE - Student and Exchange Visitor Information System (SEVIS):
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> All contracts are Firm Fixed Price with set
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monthly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  billing amounts. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> SEVIS uses a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Modular/Agile
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  methodology and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is not incorporated into the contracts. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> Because EVM requires quantification of a project plan, it is difficult to apply to discovery-driven or Agile software development projects.</div></span>
# USCG - Rescue 21:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Coast Guard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ensured
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  requirements were included in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Rescue 21 Phase II Indefinite Delivery, Indefinite Quantity (
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IDIQ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) contract with the prime contractor for the coastal phase,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     General Dynamics C4 Systems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (item #
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  above). </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> The total value of the acquisition phase of this contract is $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     643.385M.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#   The time and material contracts/task orders listed above are for various project management contract support tasks (project management, financial management, and computer database support) for the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rescue 21
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  project office at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coast Guard Headquarters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Rescue 21 Project Resident Offices
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Scottsdale
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AZ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Juneau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> The contracts awarded for
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Western Rivers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , Vessels, and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alaska Deployment are Fixed Price
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contracts,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  requirements are not included in these contracts. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  discourages the use of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on these types of contracts and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DHS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  allows for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  discretion to use
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for Firm Fixed Price,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Time
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Materia
# USCG - Ports and Waterways Safety System (PAWSS):
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PAWSS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Operations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Maintenance investment and therefore
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is not required. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> Contract performance is evaluated
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monthly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  through status reports which track
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  for operations and maintenance. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> The hours &amp; costs associated with the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     O&amp;M
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contract are verified by the project manager and contracting officer against
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hours &amp;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  costs submitted by the contractor in billings. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Discrepancies are resolved with the contractor prior to approval of payment. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">An operational analysis is also used to evaluate whether these contracts are performing within budgetary requirements. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Target deliverable dates are monitored and tracked on a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monthly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  basis. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> For all future contracts, the use of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will be evaluated on a case-by-case basis and the decision to incorporate
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will be based on overall risk reduction for the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USCG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>
# USCG - Nationwide Automatic Identification System (NAIS):
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The current production (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DME
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) contract for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NAIS - Northrop Grumman Engineering Support - HSCG2309CADP001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  /Option </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Year 1- includes requirements for the contractor to employ an EVM system which is ANSI/EIA Standard-748 compliant. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The EVM Data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is analyzed in detail on a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monthly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  basis by the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NAIS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  project team. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Future prime or production (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DME
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) contracts for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NAIS I2 Design &amp; Deployment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  beyond the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  sectors - will also include
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  recording and reporting requirements. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 15 ,2012
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the base period of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contract expired and
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Option Year 1 period
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  started. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> As a result,  the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NAIS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  project office has developed a scaled back
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM Plan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  which outlines the process for providing timely, valid, and auditable project costs and schedule status information to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NAIS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  management, team members and stakeholders. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The Plan adheres to the ANSI/EIA Standard 748-A criteria and therefore utilizes
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  principles, tools and techniques to fully integrate requirements/scope, schedule, and cost objectives. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">This EVM Plan is contained in Acquisition Plan approved by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USCG-HCA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jun 21, 2012
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and has been up loaded for your review, if needed.</div></span>
# USCG - Marine Information for Safety and Law Enforcement (MISLE):
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is required under all vehicles. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> Note that the total contract value for each vehicle represents all work performed in support of all systems hosted at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the USCG Operations Systems Center
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DHS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  approved acquisition strategy for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APLES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CTS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  replaces
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  support services task order (SETS) with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IDIQ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contracts. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">MISLE funds a specific sub
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CLIN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  under
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APLES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and also funds an allocated portion of OSC infrastructure costs.</div></span>
# USCG - Interagency Operations Centers (IOC):
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DHS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  does not require
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for contracts valued at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     less than $50 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>
# USCG - Vessel Logistics System (VLS):
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is required under all vehicles. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">  Note that the total contract value for each vehicle represents all work performed in support of all systems hosted at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the USCG Operations Systems Center
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VLS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  funds a specific
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sub-CLIN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  under
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APLES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and also funds an allocated portion of OSC infrastructure costs.</div></span>
# USCG - Infrastructure CGOne:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">These are
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DHS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contracts. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> Presence or absence of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is not controlled by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USCG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>
# USCG - Direct Access:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Labor Hour contracts only require a labor deliverable, and when these contracts were
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  established
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     several years ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and due to the nature of the required work and the evolving
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DHS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USCG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  operational environments, it was not possible to accurately estimate the scope and associated costs for many of the anticipated tasks. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">However, to reduce risk to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USCG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a hybrid approach was used: for the requirements that could be defined, a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was included with quantifiable metrics to which the contractors must adhere with penalties applied for non-conformance (is supporting FAR 37). </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PWS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  metrics include schedule-related items, cost-related items, specific deliverables (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monthly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     quarterly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     annual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  -both scheduled &amp; anticipated), and quality-related items (acceptable number of errors, review times, and remediation durations) </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Adherence to all
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DHS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  security and privacy requirements is specified.</div></span>
# USCG - Core Accounting System (CAS) Suite:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The CAS Suite is a legacy system in the O&amp;M State. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> No new development is planned. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> Earned Value is not a requirement for projects in the O&amp;M Phase.</div></span>
# USCG - CG Business Intelligence (CGBI):
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is required under the contract. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Note that the total contract value represents all work performed at OSC under the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5-year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Systems Engineering and Technical Services II task order, not just the CGBI system. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The strategy of a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five-year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  task order is addressed in the approved acquisition plan. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The current task order supports all systems hosted at the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OSC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is required under all vehicles. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> Note that the total contract value for each vehicle represents all work performed in support of all systems hosted at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the USCG Operations Systems Center
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DHS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  approved acquisition strategy for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APLES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CTS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  replaces
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  support services task order (SETS) with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IDIQ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contracts. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">CGBI funds a specific sub
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CLIN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  under
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     APLES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and also funds an allocated portion of OSC infrastructure costs. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The new Acquisition Plan is in alignment with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DHS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CG Acquisition
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  guidance. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Note-
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IDV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  GS09F0047Z has expired and no longer used. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The CGBI Program Office
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has been mandated to use these contract vehicles but does not manage them which makes reporting somewhat difficult as the sub-CLIN is not measured via
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>
# USCG - CG-LIMS:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The awarded contracts referenced do not require
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  because they are
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FFP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and are below
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USCG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  established
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  reporting thresholds. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In lieu of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CG-LIMS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  project team reviews
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monthly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  status reports to verify that work accomplished is consistent work reported in the status report. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> Regardless of contract type, size or duration, the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CG-LIMS COTR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and PM meet regularly with the contractual PMs to verify that work is being met within contractually established cost, schedule, and performance metrics. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">          </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">In addition to external contractors,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CG-LIMS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will leverage other 'in house' offices such as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ALC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , OSC, etc. to provide services to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CG-LIMS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  project. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> These intra-agency agreements include specific cost, schedule, and performance metrics similar to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CG-LIMS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contracts with external entities. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CG-LIMS PM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  meets regularly with the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USCG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  assigned PMs to verify that metrics are being met. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">              In both instances (external contractors and intra-agency entities) if metrics are not being met, remediation plans are formulated and implemented. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Regular reviews of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CG-LIMS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  risk matrix assists to identify potential issues before they occur and implement remediation plans in a proactive manner.</div></span>
# USCG - C4ISR:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Contracts that do not require
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are either below the cost threshold for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  or are not of the appropriate type of contract for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Time &amp; Materials
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ).</div></span>
# USCG - Asset Logistics Management Information System (ALMIS):
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The awarded contracts referenced above (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HSCG38-11-D-410001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HSCG38-11-
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# D-410002) do not require
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  because they are both below the threshold established by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DHS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  as per
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DHS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     102.01
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (The DHS Acquisition Manual, page
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     164
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ). </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> &lt; http://dhsconnect.dhs.gov/org/comp/oha/chiefofstaff/Documents/Acquistion page documents/HSAM 2009.pdf&gt;</div></span>
# USCG - Infrastructure - SWIRS:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The investment is in the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steady State
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  phase where earned value is not applicable.</div></span>
# ICE - TECS Modernization:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The ICE TECS Modernization Program
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  does not have EVM requirements on its current active contracts.</div></span>
# ICE - Criminal Alien Identification Initiatives (CAII):
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A majority of the CAII contracts do not require
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  as they do not meet the minimum contract value threshold (as defined in the DHS Homeland Security Acquisition Manual, subchapter
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3034.201
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ) and/or the program manager's contract risk analysis.</div></span>

# %%
html = displacy.render(docs[5].sents, style="ent")
display(HTML(html))
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Coast Guard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ensured
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  requirements were included in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Rescue 21 Phase II Indefinite Delivery, Indefinite Quantity (
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IDIQ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) contract with the prime contractor for the coastal phase,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     General Dynamics C4 Systems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (item #
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  above). </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> The total value of the acquisition phase of this contract is $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     643.385M.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#   The time and material contracts/task orders listed above are for various project management contract support tasks (project management, financial management, and computer database support) for the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rescue 21
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  project office at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coast Guard Headquarters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Rescue 21 Project Resident Offices
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Scottsdale
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AZ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Juneau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr"> The contracts awarded for
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Western Rivers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , Vessels, and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alaska Deployment are Fixed Price
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contracts,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EVM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  requirements are not included in these contracts. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  discourages the use of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on these types of contracts and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DHS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  allows for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  discretion to use
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EV
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for Firm Fixed Price,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Time
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Materia

# %%
t = dfes['CIOEvaluationComments'].tolist()[7]
import re
accomp = df1['AccomplishmentsPY'].tolist()[-1]
df1.to_dict('records')[-1]
explanation = df1['ExplanationofChangetoPYorCYFunding'].tolist()[-1]
print(explanation)
# Out:
# This is the first year of submission of an Exhibit 300 for this investment.  Therefore, there are no funding levels that have changed from the prior year.

# %%
dev_rex_list = ['NCT[ ]?\d{8}']


def get_match(text, rex):
    if isinstance(rex, (list, tuple, set)):
        rex = '(' + '|'.join(rex) + ')'
    result = re.findall(rex, text)
    return result


(
    df1['CIOEvaluationComments']
.map(lambda text: get_match(text=text.lower(), rex=('moderately high risk', 'high risk', 'low risk', 'medium risk',)))
.map(lambda x: '|'.join(x))

).sort_values()


df1['CIOEvaluationComments'].map(lambda x: get_match(
   str(x).lower(), rex=('moderately high risk','medium risk', 'high risk', 'low risk', 'medium risk', 'risk')))


df1['CIOEvaluationComments'].tolist()

example_text = "The Immigration and Customs Enforcement (ICE) Student and Exchange Visitor Information System (SEVIS) program is in the Support life cycle phase. Program leadership continues to capture, analyze, and develop mitigation strategies for likely risks in the current Risk Register. As of 3QFY15, the SEVIS program deployed SEVIS 6.20, Admissibility Indicator V1.4, and Performance Engineering 5. The releases position SEVIS to address action items specified in the February 2014 Acquisition Decision Memorandum (ADM) regarding system stabilization and vulnerability issues. Since the last assessment, the program has resolved 75% of the legacy system vulnerability issues."

doc = web("SEVIS is formulating an Analysis of Alternatives (AoA) to determine the solution set for closing the remaining vulnerabilities. Additionally, the AoA will also propose an alternative approach to support the SEVIS modernization initiative. The planned delivery of the AoA was scheduled for 1QFY16; however timeline has shifted with no update on delivery. The program continues to utilize Agile and Burn-Down charts for sprints resulting in high-quality cost estimates, which allows the program to maintain cost and schedule variance within OMB-acceptable range. The SEVIS Executive Steering Committee (ESC) continues to monitor program activities. An updated Operational Analysis scheduled for FY15 will address four key areas: customer results, innovation, strategic and business results and financial performance.")


doc22 = web("The Department of Homeland Security (DHS) Chief Information Officer (CIO) continues to assess the SEVIS program as a Moderately Low-Risk investment.',The National Protection and Programs Directorate (NPPD) National Security and Emergency Preparedness (NS/EP) Priority Telecom Services (PTS) program provides government agencies with communication capabilities during emergencies. There is no infrastructure for this investment, nor does it transmit data to anyone. This is a service and not a system. Both schedule and cost variance for PTS are within the acceptable OMB specified range. The July 2014 Operational Analysis findings indicated that PTS continues to provide cost-effective priority services to the NS/EP user community. Risks for budget and operations are identified and effectively managed. Performance metrics measure program operational efficiency, accessibility, key asset & Infrastructure protection and new customers and market penetration. These state that stakeholders and NS/EP customers are satisfied with PTS performance. Each measure achieved an Over Target condition.  The Department of Homeland Security (DHS) Chief Information Officer (CIO) assesses the NPPD NS/EP PTS program as a Low Risk investment.")

#! pip install allennlp==2.1.0 allennlp-models==2.1.0

doc = web(example_text)
html = displacy.render(doc.sents, style="ent")

doc1 = web("The Transportation Worker Identification Credential (TWIC) program was established pursuant to 102 of the Maritime Transportation Safety Act of 2002 (MTSA) and 104 of the Security and Accountability for Every Port Act of 2006 (SAFE Port Act) (October 2006).")

doc2= web("These statutes require DHS to prevent individuals from entering a secure area of a vessel or facility unless the individual holds a transportation security card or is accompanied by another individual who holds a card.")


doc3 = web("Contribution to Mission Delivery or Agency Management Support Functions: In accordance with the DHS Functional Capabilities and Activities Catalog, Version 1.0, dated January 2013, the TWIC program supports the PREVENTING TERRORISM AND ENHANCING SECURITY. Mission and the Screening function as listed in the Capability Portfolio.")
options = {"compact": True, "bg": "#09a3d5",
           "color": "white", "font": "Source Sans Pro"}
displacy.render([doc1, doc2, doc3], style="dep", options=options)


#html = displacy.render([doc1, doc2, doc3], style="dep", page=True)
#display(HTML(html))
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Immigration and Customs Enforcement (ICE) Student and Exchange Visitor Information System
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (SEVIS) program is in the Support life cycle phase. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Program leadership continues to capture, analyze, and develop mitigation strategies for likely risks in the current Risk Register. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">As of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3QFY15
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , the SEVIS program deployed SEVIS
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6.20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , Admissibility Indicator V1.4, and
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Performance Engineering 5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">The releases position SEVIS to address action items specified in the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February 2014
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  Acquisition Decision Memorandum (ADM) regarding system stabilization and vulnerability issues. </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">Since the last assessment, the program has resolved
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     75%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of the legacy system vulnerability issues.</div></span>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7133d7db2e6148acaee589e51110fcb5-0" class="displacy" width="5900" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Transportation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Worker</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Identification</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Credential (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">TWIC)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">program</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">established</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">pursuant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">102</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Maritime</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">Transportation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Safety</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">Act</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">2002 (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">MTSA)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">104</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">Security</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">Accountability</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">Every</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">Port</tspan>
#     <tspa

# %%
# Data Analyses Libraries
import unicodedata
import warnings

warnings.simplefilter('ignore')

! pip install jsonlines

# Data Analyses Libraries
import jsonlines
import pandas as pd
import requests
import re

# Importing Data plotting libraries
import matplotlib.pyplot as plt

# Other Miscallaneous Libraries
import warnings

warnings.filterwarnings('ignore')

# Import libraries

from bs4 import BeautifulSoup
import ujson

# importing plotly libraies an dqtdm
import plotly.graph_objects as go
from collections import defaultdict
from pathlib import Path

plt.rcParams['figure.figsize'] = 8, 5
plt.style.use("fivethirtyeight")
pd.options.plotting.backend = "plotly"
from tqdm.notebook import tqdm_notebook

cute_color_dict = {
    'Moonrise1': ("#F3DF6C", "#CEAB07", "#D5D5D3", "#24281A"),
    'Moonrise2': ("#798E87", "#C27D38", "#CCC591", "#29211F"),
    'Moonrise3': ("#85D4E3", "#F4B5BD", "#9C964A", "#CDC08C", "#FAD77B")
}
! pip install ujson

import numpy as np
# Importing Data plotting libraries
from requests.auth import HTTPDigestAuth

# Other Miscallaneous Libraries
import warnings

warnings.filterwarnings('ignore')
# Import libraries
import datetime
import zipfile
from collections import OrderedDict
import string
from bs4 import BeautifulSoup
import gzip




def listify(val):
    if isinstance(val, str):
        return val.split('; ')
    else:
        return val


def return1or0(val):
    if str(val) == 'nan':
        return 0
    else:
        return 1


def NullUnique(df):
    """this function displays null values"""
    dic = defaultdict(list)
    for col in df.columns:
        dic['Feature'].append(col)
        dic['NumUnique'].append(len(df[col].unique()))
        dic['NumNull'].append(df[col].isnull().sum())
        dic['%Null'].append(round(df[col].isnull().sum() / df.shape[0] * 100, 2))
    return pd.DataFrame(dict(dic)).sort_values(['%Null'], ascending=False).style.background_gradient()


def get_age(age_str):
    if 'month' in age_str.lower():
        return np.float(returnNonList(get_match(age_str, ['\d+']))) / 12

    elif 'year' in age_str.lower():
        return np.float(returnNonList(get_match(age_str, ['\d+'])))

    else:

        return returnNonList(get_match(age_str, ['\d+']))



def reformat_entites_cortellis(entities, label='SiTargets'):
    if isinstance(entities, dict):
        entities = [entities]
    try:
        result = [{'text': ent['@originalForm'], 'start': ent['@start'], 'end': ent['@end'], 'label': ent['@type']} for ent in entities
              if ent['@type'] == label]
    except Exception as e:
        print(repr(e), f'method: pipe_ents , entities : {entities} , ent_type : {label}')
        result = []
    return result


def filter_ents(entities):
    if isinstance(entities, dict):
        entities = [entities]
    seen_indices = set()
    ents_to_keep = []
    for ent in entities:
        ent_range = set(range(int(ent['@start']),
                              int(ent['@end'])+1))
        if ent_range.intersection(seen_indices):
            continue
        seen_indices = seen_indices.union(ent_range)
        ents_to_keep.append(ent)
    return ents_to_keep


def ents_to_dict(entities):
    ent_dict = {}
    for ent in entities:
        ent_type = ent.get('@type')
        if not ent_type:
            continue
        if ent_type in ent_dict.keys():
            ent_dict[ent_type].append(ent)
        else:
            ent_dict[ent_type] = [ent]
    return ent_dict

def read_jsonl(file_path):
    """Read a .jsonl file and yield its contents line by line.
    file_path (unicode / Path): The file path.
    YIELDS: The loaded JSON contents of each line.
    """
    # cnt = 0
    with Path(file_path).open('r', encoding='utf8') as f:
        for line in f:
            # cnt += 1
            try:  # hack to handle broken jsonl
                yield ujson.loads(line.strip())
            except ValueError:
                continue


dev_rex_list = ['NCT[ ]?\d{8}']


def get_match(text, rex):
    if isinstance(rex, (list, tuple, set)):
        rex = '(' + '|'.join(rex) + ')'
    result = re.findall(rex, text)
    return result


def unorder_dict(x):
    if isinstance(x, OrderedDict):
        return {k: unorder_dict(v) for k, v in x.items()}
    elif isinstance(x, list):
        return [unorder_dict(v) for v in x]
    else:
        return x


toeval = lambda x: eval(x) if isinstance(x, str) and x[0] == '[' else x
tolist = lambda x: x if isinstance(x, list) else (x if pd.isnull(x) else [x])


def get_weights_from_terms(d, average=False):
    """want to add heigher weright for words more similar to aut"""

    if not average:
        return np.sum(list(d.values()))

    else:
        n = len(t)
        return np.sum(list(d.values())) / n


def get_dict_withind_interest(d_, kw):
    return_dict = {}
    dww = d_.get('w').lower()
    if kw.lower() in dww.lower():
        return_dict[t] = kw

    t = d_.get('t')
    if strip_punctuation(kw.lower()) in strip_punctuation(t.lower()):
        return_dict[t] = kw

    return return_dict


def term_in_val(val, term):
    if term in val:
        return True
    else:
        return False


def write_jsonl(file_path, lines):
    """
    wrts a .jsonl file and dump contents.
    file_path (unicode / Path): The path to the output file.
    lines (list): The JSON-serializable contents of each line.
    """
    data = [ujson.dumps(line, escape_forward_slashes=False) for line in lines]
    Path(file_path).open('w', encoding='utf-8').write('\n'.join(data))


def make_generator(file_name, sep=","):
    """this function uses a generator"""
    qlines = (line for line in open(file_name))
    list_line = (s.rstrip().split(sep) for s in lines)
    cols = next(list_line)
    df_dicts = (dict(zip(cols, data)) for data in list_line)
    return df_dicts


def items_present_test(input_list, clist):
    """
    Check if any of the items in clist are in input_list
    :param input_list: a list to look for them in
    :param clist: things you're looking for
    :return:
    """
    return any(x in input_list for x in clist)


def lexical_diversity(my_text_data):
    """
    input is list of text data
    output gives diversity_score
    """
    word_count = len(my_text_data)
    vocab_size = len(set(my_text_data))
    diversity_score = word_count / vocab_size
    return diversity_score


def diff_bwli(li1, li2):
    """
    this fxn returns difference between two lists
    :param li1:
    :param li2:
    :return:
    """
    return (list(set(li1) - set(li2)))


def read_gz(filename, delimiter=','):
    with gzip.open(filename, 'r') as reader:
        data = pd.read_csv(reader, delimiter=delimiter)
    return data


def pipe_ents(entities, label):
    return ' | '.join(list(set([ent['text'] for ent in entities if ent['label'] == label])))


def cln(i, extent=1):
    """
    String white space 'cleaner'.
    :param i:
    :param extent: 1 --> all white space reduced to length 1; 2 --> removal of all white space.
    :return:
    """

    if isinstance(i, str) and i != "":
        if extent == 1:
            return re.sub(r"\s\s+", " ", i)
        elif extent == 2:
            return re.sub(r"\s+", "", i)
    else:
        return i


def partial_match(input_str, looking_for):
    """
    :param input_str:
    :param looking_for:
    :return:
    """

    if isinstance(input_str, str) and isinstance(looking_for, str):
        return cln(looking_for.lower(), 1) in cln(input_str.lower(), 1)
    else:
        return False


stats_dict = {
    'sum': 'TotalCount',
    'average': 'Avg',
    'mean': 'Avg',
    'median': 'Median',

}


def get_stat(df, label, aggfunc):
    name_ = stats_dict.get(aggfunc)
    return pd.pivot_table(data=df, index='authorId', values=label, aggfunc=aggfunc).rename(
        columns={label: label.split('N_')[-1].title() + name_}).round(1)


def get_counts(l):
    """
    returns number of items within a list (can be picturay items, etc)
    :param l:
    :return:
    """
    return len(l)


def normalize_dataframe(df, columns):
    """
    uses min max scaling
    :param df: pandas dataframe object
    :param columns: list of nominal features
    :return: scaled dataframe with column values processed with min max scaling
    """

    result = df.copy()
    for feature_name in columns:
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        result[feature_name] = (df[feature_name] - min_value) / (max_value - min_value)
    return result


def get_list_if_str(val, key):
    if val == None:
        return []
    v = val.get(key)
    if isinstance(v, list):
        return v
    elif isinstance(v, str):
        return [v]
    else:
        return val


def isinList(val, list_):
    if val in list_:
        return 1
    else:
        return 0


def create_count_bucket(val):
    """creates bucket based on count"""
    if val > 0:
        return 1
    else:
        return 0


def read_delim(map_file, sep='\t'):
    """fxn to read in delim files"""
    return pd.read_csv(map_file, sep=sep)


def flatten_json(y):
    """
    this flattens_json obj
    adds begining key to beginning
    """
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out


def cleanAge(age):
    if len(re.findall(r'\(.*\)', age)):
        return re.findall(r'\(.*\)', age)[0]
    return '(' + age + ')'


def returnNonList(val):
    if not isinstance(val, list):
        return val
    if isinstance(val, list):
        if len(val) == 1:
            return val[0]
        else:
            return '|'.join(val)


transtable = str.maketrans(dict.fromkeys(string.punctuation))


def to_string(s):
    """
    takes input s and returns a string type and encoding if necessary
    """
    try:
        return str(s)
    except:
        # Change the encoding type if needed
        return s.encode('utf-8')


def unicodeToAscii(s):
    """
    input: string
    output: string ascii
    """
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )


def strip_punctuation(input_string):
    """
    cleans string by stripping punctuation
    """

    return input_string.translate(transtable)


def create_df_from_table(table):
    """takes a bs4 soup obj and returns a list of dicts"""
    l = {}
    rows = iter(table)
    for row in rows:
        values = [col.text for col in row]

        l[values[0]] = values[1]
    return l


def replace_none(val, returnval='--'):
    if val == None:
        return returnval

    else:
        return val


def read_json(fin):
    with open(fin, 'r') as f:
        dat = ujson.load(f)
    return dat


def return_soup_from_html(path_counts):
    """returns beautfiul soup obj """
    with open(path_counts, 'r') as fin:
        soup = BeautifulSoup(fin, 'html.parser')
    return soup


today = datetime.datetime.today().strftime('%Y-%m-%d')
print(f"{today}")


def chunks(l, n):
    """Yield n number of sequential chunks from l."""
    d, r = divmod(len(l), n)
    for i in range(n):
        si = (d + 1) * (i if i < r else r) + d * (0 if i < r else i - r)
        yield l[si:si + (d + 1 if i < r else d)]


def gather_categorical_col(df, n=10):
    df = df.applymap(returnNonList)
    categorical_col = []
    for column in df.columns:
        if df[column].dtype == object and len(df[column].unique()) <= n:
            categorical_col.append(column)

            print(f"{column} : {df[column].unique()}")
            print("====================================")
    return categorical_col


flatten = lambda l: [item for sublist in l for item in sublist]


def callapisimple(url_):
    """whatever url you would like to use (cortellis endpoint )"""
    resp = requests.get(url=url_, auth=HTTPDigestAuth(KEY, PASS),
                        headers={'Accept': 'application/json'})
    return resp



def returnList(val):
    if val == None:
        return []

    elif isinstance(val, list):
        return val
    else:
        return [val]
# Out:
# Requirement already satisfied: jsonlines in /Users/isabelkayumetzger/opt/miniconda3/envs/llenv/lib/python3.8/site-packages (3.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/isabelkayumetzger/opt/miniconda3/envs/llenv/lib/python3.8/site-packages (from jsonlines) (21.4.0)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [506], in <cell line: 26>()
#      23 # Import libraries
#      25 from bs4 import BeautifulSoup
# ---> 26 import ujson
#      28 # importing plotly libraies an dqtdm
#      29 import plotly.graph_objects as go
#
# ModuleNotFoundError: No module named 'ujson'

# %%
from allennlp.predictors.predictor import Predictor
import allennlp_models.rc

predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/bidaf-elmo.2021-02-11.tar.gz")

def give_response(text_,predictor=predictor, question="What type of risk is the investment?"):
    response = predictor.predict(
    passage=text_,
    question=question
    )
    return response

r = give_response(t)

# %%
input_ = {
  "passage": "The Department of Homeland Security (DHS) Analysis & Operations (A&O) Common Operating Picture (COP) program is in the Mixed life cycle phase. Inaccurate reporting reflects the program's cost and schedule variances outside OMB acceptable thresholds.  Consequently, this will require a re-baseline of activities. The program also continues to be understaffed, which has negatively impacted program performance. Program leadership is working to reacquire manpower to adequately staff the program. Program leadership is currently working on an operational analysis (OA). The OA is expected to be approved during the next review cycle. Once the OA has been approved work will begin on updating the life cycle cost estimate (LCCE), risk management plan (RMP) and risk register.  Noting the issues significantly impacting the program the Department of Homeland Security (DHS) Chief Information Officer (CIO) downgrades the Analysis & Operations (A&O) Common Operating Picture (COP) program to a Moderately High Risk investment.",
  "question": "What type of risk is this investment?"
}

r2 = give_response(t)

# %%
r2.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [508], in <cell line: 1>()
# ----> 1 r2.keys()
#
# NameError: name 'r2' is not defined

# %%
r2['best_span_str']

# %%
df1['EAandInnovation'][6]
# Out:
# 'SEVIS is being incrementally enhanced to overcome technical / programmatic limitations in the current system, but is constrained to be developed under the O&M Phase using current infrastructure and DHS-approved functionalities per the Acquisition Decision Memorandum of 14 February, 2013. During this enhancement effort, ICE will attempt to bring SEVIS into better alignment with the ICE target EA while identifying capabilities within the enterprise that can be leveraged during the modernization. The system will also be designed to allow reuse of its core components where appropriate value has been identified.'

# %%
df1.to_dict('records')[6]
# Out:
# {'UniqueInvestmentIdentifier': '024-000005363',
#  'BusinessCaseID': '143',
#  'AgencyCode': '24',
#  'AgencyName': 'Department of Homeland Security',
#  'BureauCode': '55',
#  'BureauName': 'Immigration and Customs Enforcement',
#  'InvestmentTitle(ITPortfolio)': 'ICE - Student and Exchange Visitor Information System (SEVIS)',
#  'BriefSummary': "The purpose of SEVIS is to fulfill a legislative mandate to electronically collect certain information from approved schools and exchange programs on nonimmigrant students, exchange visitors, and their dependents. The goal of SEVIS is to track information on nonimmigrants who are participating in the U.S. education system or designated exchange visitor program throughout the duration of their approved stay. Nonimmigrants may temporarily come to the US to study under three classes of admission: F for academic and language students, M for vocational students, and J for exchange visitors. SEVIS greatly improved efficiencies by using electronic means to capture critical F/M/J nonimmigrant information in a centralized repository. The use of the SEVIS electronic system increases data accuracy, reduces the time needed to gather and distribute information, improves the experience of school/program officials and nonimmigrants, and significantly increases data sharing across multiple government agencies reducing duplication of effort. Efficiencies are further improved through the ability of the web-based SEVIS application to be used in real-time for data updates and queries which reduces the time needed to gather and distribute information. SEVIS supports the DHS Mission by providing critical information needed to enforce immigration laws. The Student and Exchange Visitor Program (SEVP) within the ICE Office of Homeland Security Investigations (HSI) is the business sponsor that funds and manages SEVIS. SEVIS also supports the Department of State (DoS) Office of Private Sector Exchange in its mission. Immigration and Customs Enforcement (ICE) Office of the Chief Information Officer (OCIO) provides IT program and project management support to SEVP. Stakeholders include DHS ICE and DoS government users; customers are users from the academia and programs sponsoring F, M, or J status nonimmigrants; nonimmigrant students and exchange visitors and their dependents. In addition, SEVIS shares data with agencies' and organizations' systems including, DoS Consular Consolidated Database (CCD), USCIS Electronic Immigration System (ELIS), Foreign Terrorist Tracking Task Force (FTTTF), Department of Treasury I-901 Fee Pay system, Student and Exchange Visitor Program Automated Management System (SEVPAMS), CBP TECS, Arrival and Departure Information System (ADIS).",
#  'ProgramCodeFPI': '024-048 : Homeland Security Investigations',
#  'EAandInnovation': 'SEVIS is being incrementally enhanced to overcome technical / programmatic limitations in the current system, but is constrained to be developed under the O&M Phase using current infrastructure and DHS-approved functionalities per the Acquisition Decision Memorandum of 14 February, 2013. During this enhancement effort, ICE will attempt to bring SEVIS into better alignment with the ICE target EA while identifying capabilities within the enterprise that can be leveraged during the modernization. The system will also be designed to allow reuse of its core components where appropriate value has been identified.',
#  'ROIDescription': "SEVIS is currently the only system designed to identify how many students and exchange visitors are in the United States, what they are doing, where they are located, whether they are participating in Optional Practical Training, or are Science, Technology, Engineering and Mathematics students.  Previously a paper based process, SEVIS implementation provided efficiencies by using electronic means to capture critical F/M/J nonimmigrant information in a centralized repository. The use of the SEVIS electronic system increases data accuracy, reduces the time needed to gather and distribute information, and improves the experience of school/program officials and nonimmigrants. SEVIS has continued to add value in the support phase. One of SEVP's missions is to strengthen the U.S. by building cross-cultural ties and attracting highly talented students and scholars. During the life of SEVIS, enhancements have been made to help facilitate the process required for foreign students and scholars coming to the United States and to minimize a perception that the United States is discouraging foreign students and scholars from coming to the U.S. These enhancements include ensuring that data is accurate so nonimmigrants are not denied a visa or entry based on incorrect information and ensuring that there are processes to quickly correct inaccurate data. Foreign student enrollment plateaued prior to and during the initial deployment of SEVIS. Between 2006 and 2012 the number of foreign students has doubled and continues to grow. Government users have also come to recognize the value of SEVIS data. A primary example is the timely data that SEVIS provides CBP, which supports CBP officers at U.S. ports of entry in making information-based decisions on granting entry for F, M, and J nonimmigrants. For the Foreign Terrorist Tracking Task Force (FTTTF) and the ICE Compliance Enforcement Unit (CEU), SEVIS has similarly become an essential tool for national security.",
#  'AccomplishmentsPY': 'ICE 1) Implemented Agile development for Operations & Maintenance (O&M) and approved functional area enhancements coding in accordance with ADM-1, 2) awarded new O&M contracts to reduce O&M costs by 25%, 3) Issued a release allowing schools to enter accreditation & Federal Aviation Administration certification information, search using the SEVIS ID, more easily correct zip codes, adjust user roles to reduce data correction requests & increase the accuracy of school and student information, 4) Acquired contract support & commenced closing vulnerabilities as approved by DHS, 5) Acquired contract support for & made progress on improving the data flow to Customs & Border Protection port of entry officers to improve nonimmigrant entry decisions, 6) Prepared acquisition documentation for the second set of DHS-approved functional area enhancements, 7) migrated to a cloud-based Development/Test environment, and 8) Commenced development of an MNS in response to the 24 February 2014 ADM.',
#  'AccomplishmentsCYBY': 'In the Current Year and Budget Year ahead ICE will (1) Recompete the SEVIS IT Planning and Architecture Team contract in an effort to increase efficiency and lower cost, (2) Award the second set of DHS-approved enhancements that will further increase information accuracy, ease the data entry into SEVIS, provide better help and instructional text on-screen, make SEVIS data more suitable to analysis for historical events and anomalous activity, and provide workflows to support nonimmigrant students transferring between schools, (3) Release the initial DHS-approved enhancements into production, (4) Release the CBP admissibility indicator into production, (5) Continue to improve SEVIS with O&M releases, (6) Develop and submit an MNS for DHS review and approval, and when the MNS is approved, (7) execute an Analysis of Alternatives to determine the solution set to close the remaining SEVIS vulnerabilities.',
#  'SharedService': 'yes',
#  'PIVEnabled': 'yes',
#  'PublicAPI': 'no',
#  'OpenDataEvaluation-SystemDesign': 'no',
#  'OpenDataEvaluation-EnterpriseDataInventory': 'yes',
#  'OpenDataEvaluation-OutputsMeetM-13-13': 'no',
#  'OpenDataEvaluation-SchemaandDictionaryDocumentedandShared': 'no',
#  'OpenDataEvaluation-NotApplicable-NotNeworModernizing': 'no',
#  'OpenDataEvaluation-NotApplicable-NotAppropriate(Comment)': nan,
#  'OpenDataEvaluation-NotYetValidatedbyCIO': 'no',
#  'FundingPY1andPrior($M)': 259.121,
#  'FundingPY($M)': 22.568,
#  'FundingCY($M)': 14.002,
#  'FundingBY($M)': 14.347,
#  'InvestmentStartYear': 2002,
#  'InvestmentEndYear': 2020,
#  'ExplanationofChangetoPYorCYFunding': 'N/A.',
#  'NoEVMExplanation': ' All contracts are Firm Fixed Price with set monthly billing amounts.  SEVIS uses a Modular/Agile methodology and EVM is not incorporated into the contracts.  Because EVM requires quantification of a project plan, it is difficult to apply to discovery-driven or Agile software development projects.',
#  'Evaluation(byAgencyCIO)': 4,
#  'CIOEvaluationComments': 'The Immigration and Customs Enforcement (ICE) Student and Exchange Visitor Information System (SEVIS) program is in the Support life cycle phase. Program leadership continues to capture, analyze, and develop mitigation strategies for likely risks in the current Risk Register. As of 3QFY15, the SEVIS program deployed SEVIS 6.20, Admissibility Indicator V1.4, and Performance Engineering 5. The releases position SEVIS to address action items specified in the February 2014 Acquisition Decision Memorandum (ADM) regarding system stabilization and vulnerability issues. Since the last assessment, the program has resolved 75% of the legacy system vulnerability issues. SEVIS is formulating an Analysis of Alternatives (AoA) to determine the solution set for closing the remaining vulnerabilities. Additionally, the AoA will also propose an alternative approach to support the SEVIS modernization initiative. The planned delivery of the AoA was scheduled for 1QFY16; however timeline has shifted with no update on delivery. The program continues to utilize Agile and Burn-Down charts for sprints resulting in high-quality cost estimates, which allows the program to maintain cost and schedule variance within OMB-acceptable range. The SEVIS Executive Steering Committee (ESC) continues to monitor program activities. An updated Operational Analysis scheduled for FY15 will address four key areas: customer results, innovation, strategic and business results and financial performance.   The Department of Homeland Security (DHS) Chief Information Officer (CIO) continues to assess the SEVIS program as a Moderately Low-Risk investment.',
#  'CIOEvaluationColor': 'Green',
#  'DateofLastUpdatetoCIOEvaluation': '07/31/2015',
#  'DateofLastChangetoCIOEvaluation': '07/31/2015',
#  'NumberofchangestoBaseline': 11.0,
#  'DateofLastBaseline': '10/14/2014',
#  'DateofLastChangetoActivities': '09/10/2014',
#  'DateofLastUpdatetoActivities': '10/28/2014',
#  'DataFreshness': 'Current',
#  'DateofLastChangetoContracts': '04/27/2015',
#  'DateofLastChangetoPerformanceMetrics': '09/10/2014',
#  'DateofLastUpdatetoPerformanceMetricActuals': '08/26/2015',
#  'DateofLastTechStat': nan,
#  'BudgetYear': 2016,
#  'DateInvestmentFirstSubmitted': '2009-06-30 00:00:00',
#  'DateofLastInvestmentDetailUpdate': '2014-09-09 08:19:42',
#  'InvestmentAutoSubmissionDate': '02/05/2015',
#  'InvestmentYears': 18,
#  'fileName': 'BusinessCase-DHS-2016.csv'}

# %%
df2 = pd.read_csv(files_[2])

# %%
df2['']
# Out:
# 0     HSIN is a DHS Mission Critical system that connects homeland security leaders and mission partne...
# 1     The purpose of the COP is to support the DHS mission of responding to threats and hazards to the...
# 2     SEVIS electronically collects certain information from approved schools and exchange programs on...
# 3     The purpose of IDENT is to provide core biometric identity services for the dissemination of ide...
# 4     The purpose of ADIS is to support activities to prevent illegal entry, exit, & overstay of forei...
# 5     The purpose of the HRIT investment is to consolidate, integrate, and modernize the Department's ...
# 6     The purpose of the National Flood Insurance Program (NFIP) Information Technology Systems and Se...
# 7     Goals, and Current or Anticipated benefits: \nThe Disaster Assistance Improvement Program (DAIP)...
# 8     The purpose of IPAWS is to deliver "an effective, reliable, integrated, flexible, and comprehens...
# 9     The LSCMS Program supports FEMA's mission of responding to all hazards expediently and efficient...
# 10    Purpose: The Transportation Worker Identification Credential (TWIC) program was established purs...
# 11    STIP is an agency-wide data information technology (IT) program that connects all Transportation...
# 12    SF supports both Missions 1 & 2 of the DHS Strategic Plan (Preventing Terrorism/ Enhancing Secur...
# 13    TIM implements TSA's centralized system for enrollments, vetting, adjudication and redress missi...
# 14    Purpose: The R21 system is an advanced command, control, and communications system that greatly ...
# 15    Purpose:\nNAIS is a data collection, processing and distribution system that provides internatio...
# 16    Purpose: The purpose of the Core Accounting System (CAS) is to serve as the primary accounting, ...
# 17    Purpose:  CG-LIMS is a technology refresh of legacy logistics IT systems using a COTS tool confi...
# 18    The purpose of the Command, Control, Communications, Computers, Intelligence, Surveillance, and ...
# 19    The purpose of LBI is to maintain technologies deployed at nearly all inbound land border vehicl...
# 20    SAP is an Enterprise Resource Planning (ERP) system and is the financial system of record for CB...
# 21    The Tactical Communications (TACCOM) Modernization investment purpose is to redesign existing La...
# 22    The Investigative Case Management system will provide improved case management functionality to ...
# 23    The purpose of ATS is to be the cornerstone of all CBPs targeting efforts.  ATS is a web-based e...
# 24    The purpose of ACE is to provide a comprehensive system that enables CBP to manage and oversee c...
# 25    The purpose of APIS is to provide CBP with an electronic data interchange to receive traveler an...
# 26    This investment supports the Enforcement and administration of immigration laws by providing the...
# 27    The purpose of the Verification Modernization (VER MOD) investment is to strengthen and improve ...
# 28    The purpose of the Program is to provide efficient and effective technology to inspect conveyanc...
# 29    The IITT Program is essential to increasing effectiveness of the USSSs information technology (I...
# 30    The purpose of TECS Mod (TM) program is to modernize the core TECS subject record and support se...
# 31    The purpose of Integrated Fixed Towers (IFT) Program is to provide automated and persistent wide...
# 32    Purpose: To replace existing technology with newer, more readily available technology and increa...
# 33    The Phoenix Program is  currently in the early stage of the obtain phase for the Pivot system wh...
# 34    The purpose of Border Patrol Enforcement Systems (BPES) is to assist the U.S. Border Patrol (USB...
# 35    The purpose of the Grants Management Modernization (GMM) Program is to transform the way FEMA ma...
# 36    The purpose of HART is to provide enduring identity services to DHS and its mission partners tha...
# 37    The Revenue Modernization (Rev Mod) program's purpose is to consolidate, automate, and streamlin...
# Name: Brief Summary, dtype: object

# %%
df2['Explanation of Change to PY or CY Funding'].dropna().tolist()
# Out:
# ['Changes to meet emerging security requirements, interoperability and hosting services, the migration to a Cloud Solution, and the planned upgrade from SharePoint-2010 to SharePoint-2016 impact the funding levels and funding categories. Additionally O&M costs for an increasing user population effect funding levels.',
#  'COP budget was increased from 3.954 to 7.33 for COP replatforming, IT Enhancements, and hosting services in DHS data center two. Major upgrades will include COOP DR, increased data feeds to NOC elements and DHS components, and RFI.',
#  'N/A.',
#  'N/A.',
#  'No significant changes in funding levels.',
#  'The Final FY15 Presidents Budget request includes two program enhancements above the FY14 enacted funding level:1) A request  for an additional $1.143M to support the implementation of the enterprise-wide Performance and Learning Management System (PALMS), and 2) A request for an additional $.0879M in support of HRIT Portfolio Management. The FY16 funding level for HRIT (appropriated) includes the FY15 Presidents Budget program enhancements as well as a mandated Department-wide 1% reduction.',
#  'FEMA - NFIP IT Systems and Services no longer includes planning activities for the replacement investment, FEMA - NFIP IT Phoenix. At IOC, FEMA - IT Systems and Service will begin transition of program services and functional shutdown.',
#  'DAIP experienced a decrease from PY16 planned budgets to CY17 due to lower funds for external agency partners from $940,000 to $628,000.',
#  'Reduced funding include: a reduction from $25.0M to $10.8M per year for FY14 and future years; additional $3M cut to both FY13 and FY14 delayed several critical milestones to FY17.  IPAWS adjusted FTE costs to reflect the latest Salary and Benefit data;  IPAWS adjusted its allocation plan for the Emergency Supplemental Appropriations Act for Defense, the Global War on Terror, and Hurricane Recovery, 2006 (Public Law 109-234) fund (Fund 78 -no year funds).',
#  "The lifetime of the investment has been extended through FY2028, rather than FY2024 reflected in last year's Presidential Budget.  A major refresh in FY2016 will extend the life of the investment to FY2028 and increases the life cycle costs by $133M.  ADE-3 and FOC pushed out from FY2014 to FY2018.",
#  'Decrease in PY 2017 funding is due to refinement of the revenue model to more accurately forecast revenue based on actual data collected over the last 5 years.This program is funded from user fees. Variances between budgetary resources and outlays are a result of the variable nature of the program. Since this is a fee based program, actual fees collected do not always correspond directly with projected fee collections.',
#  "There are no changes in funding levels for CY, however the PY budget was reduced due to the President's FY18 Budget.",
#  'There are no significant changes to the budget for PY and CY, the variance is less than 6%.  For CY to BY, the slightly above 10% in funds is for the purchase of HW to support the SF core vetting engine.',
#  'FY14, FY15 and FY16 are consistent with the LCCE and the build schedule for the TIM program.In FY14 we are funding the surface builds which requires a reduced level because the majority of the architecture will already be present from the previous builds. The same holds true for the aviation builds in FY15.  With completion in FY2016 of FOC, the TSA TIM program completes development and is in full operation across the transportation mode populations.',
#  'There are no fundamental or substantive changes.',
#  'FY2016 Cost estimates have been included in the current CIP; no other changes on previously reported fiscal years have been made.',
#  'There are no fundamental or substantive changes.',
#  'CY matches the Presidents Budget.',
#  'There are no fundamental or substantive changes.',
#  'There were no significant changes.',
#  "Unfunded requests for the program in PY2017 were fulfilled internally to OF and resulted in an increase over the President's Budget.  Funding was identified internal to OF to fund the SAP Program in CY2018 and out years to cover operations and maintenance cost estimates which resulted in the increase over the President's Budget amount from last year.",
#  'The changes will not have significant impact. The Program never receives the full funding slated in the FYHSP. Minor funding reductions will have insignificant impact as the Program has a funding mitigation strategy in place.',
#  'The program did not receive the full requested amount for PY (2017).  The program received $16M out of the requested $21M ($5M shortfall).',
#  'There are no significant changes.',
#  "There are no changes from the President's Budget for the PY and the CY.",
#  "There have been no changes for the Prior Year and the Current Year from the FY17 president's Budget.",
#  'The variance seen in FY16 from the prior year request is due to a change of program scope, as directed in the Acquisition Decision Memorandum signed by the DHS Under Secretary for Management on October 6, 2015.  The program scope now includes costs associated with the operation of E-Verify and SAVE, which are primarily related to government FTE.',
#  'No significant changes.',
#  'IITT funding is relatively flat through the Future Years Homeland Security Plan (FYHSP).  While this  funding profile results in a less than desirable rate for improvement of critical IT programs, the rate is not fully dependent on funding since a contract protest resulted in a schedule slip of approximately one year.  The result is an adequately funded program across the FYHSP.',
#  "There have been no changes for the Prior Year and the Current Year from the FY17president's Budget.",
#  'There have been no changes.',
#  'The increase in PC&I funding received in the PY (FY17) is for additional Relocatable Towers in the RGV Sector.',
#  'Any significant changes in budgeting amounts is due to the recent completion of the Life Cycle Cost Estimate in July of 2016.',
#  'There are no changes.',
#  'The funding levels for the GMM Program in Prior Year (PY) and Current Year (CY) to the proposed budget for Budget Year 2019 (BY19) are consistent for those same years. There are no changes.',
#  'During FY 2016 OBIM estimates it will accrue approximately $24M in additional recoveries.  Through analysis required for the HART Certification of Funds Memo, OBIM realized that HART didnt have sufficient budgetary resources for ADE-2A.  It was determined that any recoveries would be applied to the HART effort to ensure proper funding levels to support project affordability.  The $24M surplus in FY2016 will be applied to ensure HART affordability requirements are met.',
#  'There is no significant change in CY (FY18) funding.  PY (FY17) has been underfunded by $8.76M.  Rev Mod is anticipating a rescission of $20M against 3-year funding from FY16.']

# %%
! echo '{"sentence": "PY (FY17) has been underfunded by $8.76M."}' |     allennlp predict https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz -
# Out:
# 2022-05-13 06:34:51,619 - INFO - allennlp.common.plugins - Plugin allennlp_models available
# 2022-05-13 06:34:51,891 - INFO - allennlp.common.file_utils - cache of https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz is up-to-date
# 2022-05-13 06:34:51,891 - INFO - allennlp.models.archival - loading archive file https://storage.googleapis.com/allennlp-public-models/structured-prediction-srl-bert.2020.12.15.tar.gz from cache at /Users/isabelkayumetzger/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3
# 2022-05-13 06:34:51,893 - INFO - allennlp.models.archival - extracting archive file /Users/isabelkayumetzger/.allennlp/cache/b5f1db011cc85691a5fa2bf29e055a712261a2e5d74a74edd7da2fffc98d4ab8.4c4ac7e06ec3d85631bd26b839f90b5a375d3ceeb43e3c74f1cf4758dcee2bb3 to temp dir /var/folders/58/vp01s10j0lxd0qrrcz1hnfx80000gn/T/tmp4c8akog6
# 2022-05-13 06:34:54,814 - INFO - allennlp.common.params - dataset_reader.type = srl
# 2022-05-13 06:34:54,814 - INFO - allennlp.common.params - dataset_reader.max_instances = None
# 2022-05-13 06:34:54,814 - INFO - allennlp.common.params - dataset_reader.manual_distributed_sharding = False
# 2022-05-13 06:34:54,815 - INFO - allennlp.common.params - dataset_reader.manual_multiprocess_sharding = False
# 2022-05-13 06:34:54,815 - INFO - allennlp.common.params - dataset_reader.token_indexers = None
# 2022-05-13 06:34:54,815 - INFO - allennlp.common.params - dataset_reader.domain_identifier = None
# 2022-05-13 06:34:54,815 - INFO - allennlp.common.params - dataset_reader.bert_model_name = bert-base-uncased
# 2022-05-13 06:34:54,986 - INFO - numexpr.utils - NumExpr defaulting to 8 threads.
# 2022-05-13 06:34:56,538 - INFO - allennlp.common.params - dataset_reader.type = srl
# 2022-05-13 06:34:56,538 - INFO - allennlp.common.params - dataset_reader.max_instances = None
# 2022-05-13 06:34:56,538 - INFO - allennlp.common.params - dataset_reader.manual_distributed_sharding = False
# 2022-05-13 06:34:56,538 - INFO - allennlp.common.params - dataset_reader.manual_multiprocess_sharding = False
# 2022-05-13 06:34:56,538 - INFO - allennlp.common.params - dataset_reader.token_indexers = None
# 2022-05-13 06:34:56,538 - INFO - allennlp.common.params - dataset_reader.domain_identifier = None
# 2022-05-13 06:34:56,538 - INFO - allennlp.common.params - dataset_reader.bert_model_name = bert-base-uncased
# 2022-05-13 06:34:56,885 - INFO - allennlp.common.params - type = from_instances
# 2022-05-13 06:34:56,885 - INFO - allennlp.data.vocabulary - Loading token dictionary from /var/folders/58/vp01s10j0lxd0qrrcz1hnfx80000gn/T/tmp4c8akog6/vocabulary.
# 2022-05-13 06:34:56,886 - INFO - allennlp.common.params - model.type = srl_bert
# 2022-05-13 06:34:56,886 - INFO - allennlp.common.params - model.regularizer = None
# 2022-05-13 06:34:56,886 - INFO - allennlp.common.params - model.bert_model = bert-base-uncased
# 2022-05-13 06:34:56,886 - INFO - allennlp.common.params - model.embedding_dropout = 0.1
# 2022-05-13 06:34:56,886 - INFO - allennlp.common.params - model.initializer = <allennlp.nn.initializers.InitializerApplicator object at 0x7f9d55119640>
# 2022-05-13 06:34:56,886 - INFO - allennlp.common.params - model.label_smoothing = None
# 2022-05-13 06:34:56,887 - INFO - allennlp.common.params - model.ignore_span_metric = False
# 2022-05-13 06:34:56,887 - INFO - allennlp.common.params - model.srl_eval_path = /Users/isabelkayumetzger/opt/miniconda3/envs/llenv/lib/python3.8/site-packages/allennlp_models/structured_prediction/tools/srl-eval.pl
# 2022-05-13 06:34:59,640 - INFO - allennlp.nn.initializers - Initializing parameters
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers - Done initializing parameters; the following parameters are using their default initialization from their code
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.embeddings.LayerNorm.bias
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.embeddings.LayerNorm.weight
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.embeddings.position_embeddings.weight
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.embeddings.token_type_embeddings.weight
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.embeddings.word_embeddings.weight
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.output.LayerNorm.bias
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.output.LayerNorm.weight
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.output.dense.bias
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.output.dense.weight
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.key.bias
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.key.weight
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.query.bias
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.query.weight
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.value.bias
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.attention.self.value.weight
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.intermediate.dense.bias
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.intermediate.dense.weight
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.output.LayerNorm.bias
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.output.LayerNorm.weight
# 2022-05-13 06:34:59,643 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.output.dense.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.0.output.dense.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.output.LayerNorm.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.output.LayerNorm.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.output.dense.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.output.dense.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.self.key.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.self.key.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.self.query.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.self.query.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.self.value.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.attention.self.value.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.intermediate.dense.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.intermediate.dense.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.output.LayerNorm.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.output.LayerNorm.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.output.dense.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.1.output.dense.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.output.LayerNorm.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.output.LayerNorm.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.output.dense.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.output.dense.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.self.key.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.self.key.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.self.query.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.self.query.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.self.value.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.attention.self.value.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.intermediate.dense.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.intermediate.dense.weight
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.output.LayerNorm.bias
# 2022-05-13 06:34:59,644 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.output.LayerNorm.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.output.dense.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.10.output.dense.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.output.LayerNorm.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.output.LayerNorm.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.output.dense.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.output.dense.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.self.key.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.self.key.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.self.query.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.self.query.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.self.value.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.attention.self.value.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.intermediate.dense.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.intermediate.dense.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.output.LayerNorm.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.output.LayerNorm.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.output.dense.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.11.output.dense.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.output.LayerNorm.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.output.LayerNorm.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.output.dense.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.output.dense.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.self.key.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.self.key.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.self.query.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.self.query.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.self.value.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.attention.self.value.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.intermediate.dense.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.intermediate.dense.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.output.LayerNorm.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.output.LayerNorm.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.output.dense.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.2.output.dense.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.output.LayerNorm.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.output.LayerNorm.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.output.dense.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.output.dense.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.self.key.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.self.key.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.self.query.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.self.query.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.self.value.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.attention.self.value.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.intermediate.dense.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.intermediate.dense.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.output.LayerNorm.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.output.LayerNorm.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.output.dense.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.3.output.dense.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.output.LayerNorm.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.output.LayerNorm.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.output.dense.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.output.dense.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.self.key.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.self.key.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.self.query.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.self.query.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.self.value.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.attention.self.value.weight
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.intermediate.dense.bias
# 2022-05-13 06:34:59,645 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.intermediate.dense.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.output.LayerNorm.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.output.LayerNorm.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.output.dense.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.4.output.dense.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.output.LayerNorm.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.output.LayerNorm.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.output.dense.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.output.dense.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.self.key.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.self.key.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.self.query.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.self.query.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.self.value.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.attention.self.value.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.intermediate.dense.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.intermediate.dense.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.output.LayerNorm.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.output.LayerNorm.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.output.dense.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.5.output.dense.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.output.LayerNorm.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.output.LayerNorm.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.output.dense.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.output.dense.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.self.key.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.self.key.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.self.query.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.self.query.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.self.value.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.attention.self.value.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.intermediate.dense.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.intermediate.dense.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.output.LayerNorm.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.output.LayerNorm.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.output.dense.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.6.output.dense.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.output.LayerNorm.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.output.LayerNorm.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.output.dense.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.output.dense.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.self.key.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.self.key.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.self.query.bias
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.self.query.weight
# 2022-05-13 06:34:59,646 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.self.value.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.attention.self.value.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.intermediate.dense.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.intermediate.dense.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.output.LayerNorm.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.output.LayerNorm.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.output.dense.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.7.output.dense.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.output.LayerNorm.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.output.LayerNorm.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.output.dense.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.output.dense.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.self.key.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.self.key.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.self.query.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.self.query.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.self.value.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.attention.self.value.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.intermediate.dense.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.intermediate.dense.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.output.LayerNorm.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.output.LayerNorm.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.output.dense.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.8.output.dense.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.output.LayerNorm.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.output.LayerNorm.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.output.dense.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.output.dense.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.key.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.key.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.query.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.query.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.value.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.attention.self.value.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.intermediate.dense.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.intermediate.dense.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.LayerNorm.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.LayerNorm.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.dense.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.encoder.layer.9.output.dense.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.pooler.dense.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    bert_model.pooler.dense.weight
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    tag_projection_layer.bias
# 2022-05-13 06:34:59,647 - INFO - allennlp.nn.initializers -    tag_projection_layer.weight
# 2022-05-13 06:35:00,115 - INFO - allennlp.models.archival - removing temporary unarchived model dir at /var/folders/58/vp01s10j0lxd0qrrcz1hnfx80000gn/T/tmp4c8akog6
# input 0:  {"sentence": "PY (FY17) has been underfunded by $8.76M."}
# prediction:  {"verbs": [{"verb": "has", "description": "PY ( FY17 ) [V: has] been underfunded by $ 8.76M.", "tags": ["O", "O", "O", "O", "B-V", "O", "O", "O", "O", "O"]}, {"verb": "been", "description": "PY ( FY17 ) has [V: been] underfunded by $ 8.76M.", "tags": ["O", "O", "O", "O", "O", "B-V", "O", "O", "O", "O"]}, {"verb": "underfunded", "description": "[ARG1: PY ( FY17 )] has been [V: underfunded] [ARG2: by $ 8.76M.]", "tags": ["B-ARG1", "I-ARG1", "I-ARG1", "I-ARG1", "O", "O", "B-V", "B-ARG2", "I-ARG2", "I-ARG2"]}], "words": ["PY", "(", "FY17", ")", "has", "been", "underfunded", "by", "$", "8.76M."]}

# %%
pred = {"verbs": [{"verb": "Did", "description": "[V: Did] Uriah honestly think he could beat the game in under three hours ? .", "tags": ["B-V", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}, {"verb": "think", "description": "Did [ARG0: Uriah] [ARGM-ADV: honestly] [V: think] [ARG1: he could beat the game in under three hours] ? .", "tags": ["O", "B-ARG0", "B-ARGM-ADV", "B-V", "B-ARG1", "I-ARG1", "I-ARG1", "I-ARG1", "I-ARG1", "I-ARG1", "I-ARG1", "I-ARG1", "I-ARG1", "O", "O"]}, {"verb": "could", "description": "Did Uriah honestly think he [V: could] beat the game in under three hours ? .", "tags": ["O", "O", "O", "O", "O", "B-V", "O", "O", "O", "O", "O", "O", "O", "O", "O"]}, {"verb": "beat", "description": "Did Uriah honestly think [ARG0: he] [ARGM-MOD: could] [V: beat] [ARG1: the game] [ARGM-TMP: in under three hours] ? .", "tags": ["O", "O", "O", "O", "B-ARG0", "B-ARGM-MOD", "B-V", "B-ARG1", "I-ARG1", "B-ARGM-TMP", "I-ARGM-TMP", "I-ARGM-TMP", "I-ARGM-TMP", "O", "O"]}], "words": ["Did", "Uriah", "honestly", "think", "he", "could", "beat", "the", "game", "in", "under", "three", "hours", "?", "."]}
pred.keys()
# Out:
# dict_keys(['verbs', 'words'])

# %%
input_ =  {"sentence": "PY (FY17) has been underfunded by $8.76M."}
pred = {"verbs": [{"verb": "has", "description": "PY ( FY17 ) [V: has] been underfunded by $ 8.76M.", "tags": ["O", "O", "O", "O", "B-V", "O", "O", "O", "O", "O"]}, {"verb": "been", "description": "PY ( FY17 ) has [V: been] underfunded by $ 8.76M.", "tags": ["O", "O", "O", "O", "O", "B-V", "O", "O", "O", "O"]}, {"verb": "underfunded", "description": "[ARG1: PY ( FY17 )] has been [V: underfunded] [ARG2: by $ 8.76M.]", "tags": ["B-ARG1", "I-ARG1", "I-ARG1", "I-ARG1", "O", "O", "B-V", "B-ARG2", "I-ARG2", "I-ARG2"]}], "words": ["PY", "(", "FY17", ")", "has", "been", "underfunded", "by", "$", "8.76M."]}

[v for v in pred['verbs'] if v['verb']=='underfunded']
# Out:
# [{'verb': 'underfunded',
#   'description': '[ARG1: PY ( FY17 )] has been [V: underfunded] [ARG2: by $ 8.76M.]',
#   'tags': ['B-ARG1',
#    'I-ARG1',
#    'I-ARG1',
#    'I-ARG1',
#    'O',
#    'O',
#    'B-V',
#    'B-ARG2',
#    'I-ARG2',
#    'I-ARG2']}]

# %%
from allennlp.predictors.predictor import Predictor
import allennlp_models.tagging

predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/fine-grained-ner.2021-02-11.tar.gz")
def return_pred(s):
    r = predictor.predict(
    sentence=s #"Did Uriah honestly think he could beat The Legend of Zelda in under three hours?."
    )
    return r
# Out:
# downloading:   0%|          | 0/376524004 [00:00<?, ?B/s]

# %%
r = return_pred(s="The Immigration and Customs Enforcement (ICE) Student and Exchange Visitor Information System (SEVIS) program is in the Support life cycle phase. Program leadership continues to capture, analyze, and develop mitigation strategies for likely risks in the current Risk Register. As of 3QFY15, the SEVIS program deployed SEVIS 6.20, Admissibility Indicator V1.4, and Performance Engineering 5. The releases position SEVIS to address action items specified in the February 2014 Acquisition Decision Memorandum (ADM) regarding system stabilization and vulnerability issues. Since the last assessment, the program has resolved 75% of the legacy system vulnerability issues. SEVIS is formulating an Analysis of Alternatives (AoA) to determine the solution set for closing the remaining vulnerabilities. Additionally, the AoA will also propose an alternative approach to support the SEVIS modernization initiative. The planned delivery of the AoA was scheduled for 1QFY16; however timeline has shifted with no update on delivery. The program continues to utilize Agile and Burn-Down charts for sprints resulting in high-quality cost estimates, which allows the program to maintain cost and schedule variance within OMB-acceptable range. The SEVIS Executive Steering Committee (ESC) continues to monitor program activities. An updated Operational Analysis scheduled for FY15 will address four key areas: customer results, innovation, strategic and business results and financial performance.   The Department of Homeland Security (DHS) Chief Information Officer (CIO) continues to assess the SEVIS program as a Moderately Low-Risk investment.")

# %%
import numpy as np
r['mask']
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %%
r = return_pred(df1['EAandInnovation'][3] + df1['CIOEvaluationComments'][3])

# %%
r = return_pred(s = "The program did not receive the full requested amount for PY (2017).  The program received $16M out of the requested $21M ($5M shortfall).")

# %%
r.keys()
# Out:
# dict_keys(['logits', 'mask', 'tags', 'words'])

# %%
np.unique(r['tags'])
# Out:
# array(['B-MONEY', 'I-MONEY', 'L-MONEY', 'O'], dtype='<U7')

# %%
r['words']
# Out:
# ['The',
#  'program',
#  'did',
#  'not',
#  'receive',
#  'the',
#  'full',
#  'requested',
#  'amount',
#  'for',
#  'PY',
#  '(',
#  '2017',
#  ')',
#  '.',
#  'The',
#  'program',
#  'received',
#  '$',
#  '16',
#  'M',
#  'out',
#  'of',
#  'the',
#  'requested',
#  '$',
#  '21',
#  'M',
#  '(',
#  '$',
#  '5',
#  'M',
#  'shortfall',
#  ')',
#  '.']

# %%
df2022, col_d = craete_df(files_[-1])
# Out:
# 37
# (41, 41)
# ../data/bdcase/Business_Case-DHS-2022.csv

# %%
df2022.columns
# Out:
# Index(['UniqueInvestmentIdentifier', 'BusinessCaseID', 'InvestmentType',
#        'InfrastructureManagementCategory', 'AgencyCode', 'AgencyName',
#        'BureauCode', 'BureauName', 'InvestmentTitle',
#        'AgencyStrategicObjectives/AgencyPriorityGoals', 'ROIDescription',
#        'InvestmentSharedService', 'PlannedSharedService',
#        'PaperworkReductionActOMBControlNumber(s)', 'PMName',
#        'PMQualifications', 'FundingPY1andPrior($M)', 'FundingPY($M)',
#        'FundingCY($M)', 'FundingBY($M)', 'InvestmentStartYear',
#        'InvestmentEndYear', 'ExplanationofChangetoPYorCYFunding',
#        'AnalysisConclusion', 'Evaluation(byAgencyCIO)',
#        'CIOEvaluationComments', 'ConsecutiveMonthswithRedCIOEval',
#        'DateofLastUpdatetoCIOEvaluation', 'DateofLastChangetoCIOEvaluation',
#        'NumberofchangestoBaseline', 'DateofLastBaseline',
#        'DateofLastChangetoActivities', 'DateofLastUpdatetoActivities',
#        'DataFreshness', 'DateofLastChangetoPerformanceMetrics',
#        'DateofLastUpdatetoPerformanceMetricActuals', 'BudgetYear',
#        'DateInvestmentFirstSubmitted', 'DateofLastInvestmentDetailUpdate',
#        'InvestmentAutoSubmissionDate', 'InvestmentYears', 'fileName'],
#       dtype='object')

# %%
df2022.describe()
# Out:
#        FundingPY1andPrior($M)  FundingPY($M)  FundingCY($M)  FundingBY($M)  \
# count               41.000000      41.000000      41.000000      41.000000
# mean               634.567537      53.749073      52.820171      54.457195
# std                856.392561      48.966734      51.862731      55.821558
# min                  0.000000       0.000000       2.136000       2.137000
# 25%                122.403000      19.792000      17.468000      16.568000
# 50%                385.098000      29.284000      28.142000      27.542000
# 75%                675.838000      81.368000      76.500000      77.722000
# max               4031.198000     180.216000     206.731000     211.646000
#
#        InvestmentStartYear  InvestmentEndYear  Evaluation(byAgencyCIO)  \
# count            41.000000          41.000000                41.000000
# mean           2007.634146        2028.243902                 3.219512
# std               6.628560           4.465313                 0.570622
# min            1995.000000        2021.000000                 2.000000
# 25%            2003.000000        2025.000000                 3.000000
# 50%            2007.000000        2028.000000                 3.000000
# 75%            2012.000000        2030.000000                 4.000000
# max            2022.000000        2040.000000                 4.000000
#
#        ConsecutiveMonthswithRedCIOEval  NumberofchangestoBaseline  BudgetYear  \
# count                        41.000000                  40.000000        41.0
# mean                          1.829268                   9.725000      2022.0
# std                           8.142182                   5.002499         0.0
# min                           0.000000                   1.000000      2022.0
# 25%                           0.000000                   5.750000      2022.0
# 50%                           0.000000                  10.000000      2022.0
# 75%                           0.000000                  13.000000      2022.0
# max                          49.000000                  21.000000      2022.0
#
#        InvestmentYears
# count        41.000000
# mean         20.609756
# std           6.833294
# min           7.000000
# 25%          15.000000
# 50%          21.000000
# 75%          25.000000
# max          40.000000

# %%
df2021, cols2021_d = craete_df(files_[-2])
df2021
# Out:
# 37
# (40, 41)
# ../data/bdcase/Business_Case-DHS-2021.csv
#    UniqueInvestmentIdentifier BusinessCaseID InvestmentType  \
# 0               024-000006079            193  01 - Major IT
# 1               024-000007333            168  01 - Major IT
# 2               024-000005605            172  01 - Major IT
# 3               024-000003015            319  01 - Major IT
# 4               024-000009102            134  01 - Major IT
# 5               024-000003029            327  01 - Major IT
# 6               024-000005628            170  01 - Major IT
# 7               024-000001226            155  01 - Major IT
# 8               024-000006005            195  01 - Major IT
# 9               024-000006104            201  01 - Major IT
# 10              024-000005053            314  01 - Major IT
# 11              024-000005116            303  01 - Major IT
# 12              024-000005056            304  01 - Major IT
# 13              024-000005138            316  01 - Major IT
# 14              024-000005119            389  01 - Major IT
# 15              024-000005052            312  01 - Major IT
# 16              024-999994100            166  01 - Major IT
# 17              024-000006343            204  01 - Major IT
# 18              024-000005072           1104  01 - Major IT
# 19              024-000007001            167  01 - Major IT
# 20              024-000007127            161  01 - Major IT
# 21              024-000005064            307  01 - Major IT
# 22              024-000005664            173  01 - Major IT
# 23              024-000005358            308  01 - Major IT
# 24              024-000005217           1107  01 - Major IT
# 25              024-000005220           1109  01 - Major IT
# 26              024-000009567           1917  01 - Major IT
# 27              024-000005236           1926  01 - Major IT
# 28              024-000005363            143  01 - Major IT
# 29              024-000009561            152  01 - Major IT
# 30              024-000009560            151  01 - Major IT
# 31              024-000007128           1279  01 - Major IT
# 32              024-000007547           1684  01 - Major IT
# 33              024-000005246           1602  01 - Major IT
# 34              024-000005253           1686  01 - Major IT
# 35              024-000005257           1687  01 - Major IT
# 36              024-000005254           1912  01 - Major IT
# 37              024-000005265           1876  01 - Major IT
# 38              024-000000610           1902  01 - Major IT
# 39              024-000005710           1969  01 - Major IT
#
#    InfrastructureManagementCategory AgencyCode  \
# 0               01 - Not Applicable         24
# 1               01 - Not Applicable         24
# 2               01 - Not Applicable         24
# 3               01 - Not Applicable         24
# 4               01 - Not Applicable         24
# 5               01 - Not Applicable         24
# 6               01 - Not Applicable         24
# 7               01 - Not Applicable         24
# 8               01 - Not Applicable         24
# 9               01 - Not Applicable         24
# 10              01 - Not Applicable         24
# 11              01 - Not Applicable         24
# 12              01 - Not Applicable         24
# 13              01 - Not Applicable         24
# 14              01 - Not Applicable         24
# 15              01 - Not Applicable         24
# 16              01 - Not Applicable         24
# 17              01 - Not Applicable         24
# 18              01 - Not Applicable         24
# 19              01 - Not Applicable         24
# 20              01 - Not Applicable         24
# 21              01 - Not Applicable         24
# 22              01 - Not Applicable         24
# 23              01 - Not Applicable         24
# 24              01 - Not Applicable         24
# 25              01 - Not Applicable         24
# 26              01 - Not Applicable         24
# 27              01 - Not Applicable         24
# 28              01 - Not Applicable         24
# 29              01 - Not Applicable         24
# 30              01 - Not Applicable         24
# 31              01 - Not Applicable         24
# 32              01 - Not Applicable         24
# 33              01 - Not Applicable         24
# 34              01 - Not Applicable         24
# 35              01 - Not Applicable         24
# 36              01 - Not Applicable         24
# 37              01 - Not Applicable         24
# 38              01 - Not Applicable         24
# 39              01 - Not Applicable         24
#
#                          AgencyName BureauCode  \
# 0   Department of Homeland Security         60
# 1   Department of Homeland Security         70
# 2   Department of Homeland Security         45
# 3   Department of Homeland Security         30
# 4   Department of Homeland Security         10
# 5   Department of Homeland Security         30
# 6   Department of Homeland Security         45
# 7   Department of Homeland Security          0
# 8   Department of Homeland Security         60
# 9   Department of Homeland Security         60
# 10  Department of Homeland Security         58
# 11  Department of Homeland Security         58
# 12  Department of Homeland Security         58
# 13  Department of Homeland Security         58
# 14  Department of Homeland Security         58
# 15  Department of Homeland Security         58
# 16  Department of Homeland Security          0
# 17  Department of Homeland Security         60
# 18  Department of Homeland Security         58
# 19  Department of Homeland Security         70
# 20  Department of Homeland Security         70
# 21  Department of Homeland Security         58
# 22  Department of Homeland Security         45
# 23  Department of Homeland Security         55
# 24  Department of Homeland Security         58
# 25  Department of Homeland Security         58
# 26  Department of Homeland Security         65
# 27  Department of Homeland Security         58
# 28  Department of Homeland Security         55
# 29  Department of Homeland Security         58
# 30  Department of Homeland Security         10
# 31  Department of Homeland Security         70
# 32  Department of Homeland Security         70
# 33  Department of Homeland Security         58
# 34  Department of Homeland Security         10
# 35  Department of Homeland Security         58
# 36  Department of Homeland Security         58
# 37  Department of Homeland Security         58
# 38  Department of Homeland Security         10
# 39  Department of Homeland Security         45
#
#                                       BureauName  \
# 0                      United States Coast Guard
# 1            Federal Emergency Management Agency
# 2         Transportation Security Administration
# 3           Citizenship and Immigration Services
# 4         Departmental Management and Operations
# 5           Citizenship and Immigration Services
# 6         Transportation Security Administration
# 7                Department of Homeland Security
# 8                      United States Coast Guard
# 9                      United States Coast Guard
# 10            U.S. Customs and Border Protection
# 11            U.S. Customs and Border Protection
# 12            U.S. Customs and Border Protection
# 13            U.S. Customs and Border Protection
# 14            U.S. Customs and Border Protection
# 15            U.S. Customs and Border Protection
# 16               Department of Homeland Security
# 17                     United States Coast Guard
# 18            U.S. Customs and Border Protection
# 19           Federal Emergency Management Agency
# 20           Federal Emergency Management Agency
# 21            U.S. Customs and Border Protection
# 22        Transportation Security Administration
# 23      U.S. Immigration and Customs Enforcement
# 24            U.S. Customs and Border Protection
# 25            U.S. Customs and Border Protection
# 26  National Protection and Programs Directorate
# 27            U.S. Customs and Border Protection
# 28      U.S. Immigration and Customs Enforcement
# 29            U.S. Customs and Border Protection
# 30        Departmental Management and Operations
# 31           Federal Emergency Management Agency
# 32           Federal Emergency Management Agency
# 33            U.S. Customs and Border Protection
# 34        Departmental Management and Operations
# 35            U.S. Customs and Border Protection
# 36            U.S. Customs and Border Protection
# 37            U.S. Customs and Border Protection
# 38        Departmental Management and Operations
# 39        Transportation Security Administration
#
#                                                   InvestmentTitle  \
# 0                                                USCG - Rescue 21
# 1         FEMA - Logistics Supply Chain Management System (LSCMS)
# 2                                             TSA - Secure Flight
# 3                                          USCIS - Transformation
# 4        DHS - CIO - Homeland Security Information Network (HSIN)
# 5                        USCIS - Verification Modernization (VER)
# 6    TSA - Transportation Worker Identification Credential (TWIC)
# 7                                              DHS - CHCO - HR-IT
# 8        USCG - Nationwide Automatic Identification System (NAIS)
# 9                             USCG - Core Accounting System (CAS)
# 10                   CBP - Automated Commercial Environment (ACE)
# 11                                  CBP - Land Border Integration
# 12                                                      CBP - SAP
# 13                     CBP - Advance Passenger Information (APIS)
# 14           CBP - Non-Intrusive Inspection (NII) Systems Program
# 15             CBP - Automated Targeting System (ATS) Maintenance
# 16             FEMA - Disaster Assistance Improvement Plan (DAIP)
# 17                                                   USCG - C4ISR
# 18                                       CBP - TECS Modernization
# 19        FEMA - Integrated Public Alert & Warning System (IPAWS)
# 20        FEMA - NFIP Information Technology Systems and Services
# 21          CBP - Tactical Communications (TAC-COM) Modernization
# 22    TSA - Technology Infrastructure Modernization (TIM) Program
# 23                                       ICE - TECS Modernization
# 24                                  CBP - Integrated Fixed Towers
# 25  CBP - Remote Video Surveillance System (RVSS) Upgrade Program
# 26                                            CISA - CISA Gateway
# 27                        CBP - Cross Border Tunnel Threat (CBTT)
# 28  ICE - Student and Exchange Visitor Information System (SEVIS)
# 29          CBP - Arrival and Departure Information System (ADIS)
# 30        DHS - Automated Biometric Identification System (IDENT)
# 31                                                   FEMA - PIVOT
# 32                         FEMA - Grants Management Modernization
# 33                 CBP - Border Patrol Enforcement Systems (BPES)
# 34          DHS - Homeland Advanced Recognition Technology (HART)
# 35                           CBP - Revenue Modernization (RevMod)
# 36                  CBP - Mobile Video Surveillance System (MVSS)
# 37                                     CBP - Biometric Entry-Exit
# 38                   DHS - Financial Systems Modernization - Trio
# 39               TSA - Credential Authentication Technology (CAT)
#
#      AgencyStrategicObjectives/AgencyPriorityGoals  ...  \
# 0                       024SO18227 - Not Available  ...
# 1                       024SO18227 - Not Available  ...
# 2                       024SO18227 - Not Available  ...
# 3   024APG18014 - Enhance Southern Border Security  ...
# 4                       024SO18227 - Not Available  ...
# 5                       024SO18227 - Not Available  ...
# 6                       024SO18227 - Not Available  ...
# 7                       024SO18227 - Not Available  ...
# 8   024APG18014 - Enhance Southern Border Security  ...
# 9                       024SO18227 - Not Available  ...
# 10                      024SO18227 - Not Available  ...
# 11                      024SO18227 - Not Available  ...
# 12                      024SO18227 - Not Available  ...
# 13                      024SO18227 - Not Available  ...
# 14                      024SO18227 - Not Available  ...
# 15                      024SO18227 - Not Available  ...
# 16                      024SO18227 - Not Available  ...
# 17  024APG18015 - Strengthen Federal Cybersecurity  ...
# 18                      024SO18227 - Not Available  ...
# 19                      024SO18227 - Not Available  ...
# 20                      024SO18227 - Not Available  ...
# 21  024APG18014 - Enhance Southern Border Security  ...
# 22                      024SO18227 - Not Available  ...
# 23                      024SO18227 - Not Available  ...
# 24  024APG18014 - Enhance Southern Border Security  ...
# 25  024APG18014 - Enhance Southern Border Security  ...
# 26                      024SO18227 - Not Available  ...
# 27  024APG18014 - Enhance Southern Border Security  ...
# 28                      024SO18227 - Not Available  ...
# 29                      024SO18227 - Not Available  ...
# 30                      024SO18227 - Not Available  ...
# 31                      024SO18227 - Not Available  ...
# 32                      024SO18227 - Not Available  ...
# 33  024APG18014 - Enhance Southern Border Security  ...
# 34                      024SO18227 - Not Available  ...
# 35                      024SO18227 - Not Available  ...
# 36  024APG18014 - Enhance Southern Border Security  ...
# 37                      024SO18227 - Not Available  ...
# 38                      024SO18227 - Not Available  ...
# 39                      024SO18227 - Not Available  ...
#
#    DateofLastUpdatetoActivities    DataFreshness  \
# 0                9/20/2018 1:08  Update Required
# 1              10/30/2019 15:05  Update Required
# 2               7/30/2020 21:12  Update Required
# 3               4/30/2020 13:55  Update Required
# 4               4/30/2020 13:55  Update Required
# 5              11/27/2019 17:49  Update Required
# 6               4/30/2020 13:55  Update Required
# 7               5/31/2019 20:44  Update Required
# 8               6/30/2020 15:56  Update Required
# 9               9/17/2019 19:03  Update Required
# 10             11/26/2019 17:21  Update Required
# 11             11/26/2019 17:20  Update Required
# 12              8/31/2020 17:33  Update Required
# 13              7/30/2020 21:12  Update Required
# 14              8/31/2020 17:33  Update Required
# 15              7/30/2020 21:12  Update Required
# 16              8/31/2020 17:33  Update Required
# 17              6/30/2020 15:57  Update Required
# 18              8/31/2020 17:33  Update Required
# 19              8/31/2020 17:33  Update Required
# 20               9/11/2013 7:43  Update Required
# 21              8/31/2020 17:33  Update Required
# 22              8/31/2020 17:33  Update Required
# 23             10/30/2019 15:06  Update Required
# 24              7/30/2020 21:13  Update Required
# 25              8/31/2020 17:33  Update Required
# 26             10/30/2019 20:27  Update Required
# 27              6/30/2020 15:57  Update Required
# 28              7/31/2019 20:10  Update Required
# 29              6/30/2020 15:57  Update Required
# 30              7/30/2020 21:13  Update Required
# 31              6/30/2020 15:57  Update Required
# 32              8/31/2020 17:32  Update Required
# 33              8/31/2020 17:34  Update Required
# 34              5/29/2020 13:35  Update Required
# 35              7/30/2020 21:13  Update Required
# 36              4/30/2020 13:56  Update Required
# 37              8/31/2020 17:34  Update Required
# 38              9/17/2019 19:04  Update Required
# 39             11/26/2019 17:20  Update Required
#
#    DateofLastChangetoPerformanceMetrics  \
# 0                       9/17/2019 19:02
# 1                       4/30/2020 18:02
# 2                       9/17/2019 19:02
# 3                       5/29/2020 13:35
# 4                       9/17/2019 19:02
# 5                      12/23/2019 16:28
# 6                       9/17/2019 19:02
# 7                       8/31/2020 17:32
# 8                       9/17/2019 19:02
# 9                      10/30/2019 15:06
# 10                      9/17/2019 19:03
# 11                      1/30/2020 22:52
# 12                      9/17/2019 19:03
# 13                      9/17/2019 19:03
# 14                      3/31/2020 15:49
# 15                      9/17/2019 19:03
# 16                      9/17/2019 19:03
# 17                      9/17/2019 19:03
# 18                     10/30/2019 15:06
# 19                      9/17/2019 19:04
# 20                      9/17/2019 19:04
# 21                      9/17/2019 19:04
# 22                      1/30/2020 22:52
# 23                      9/17/2019 19:04
# 24                      1/30/2020 22:52
# 25                      9/17/2019 19:04
# 26                       7/2/2020 15:46
# 27                                  NaN
# 28                      9/17/2019 19:04
# 29                      3/31/2020 15:49
# 30                     12/23/2019 16:28
# 31                     11/27/2019 17:49
# 32                                  NaN
# 33                      9/17/2019 19:04
# 34                                  NaN
# 35                       9/9/2019 19:18
# 36                      9/17/2019 19:04
# 37                      9/17/2019 19:04
# 38                                  NaN
# 39                      9/17/2019 19:43
#
#    DateofLastUpdatetoPerformanceMetricActuals BudgetYear  \
# 0                             8/31/2020 17:33       2021
# 1                             8/31/2020 17:33       2021
# 2                             8/31/2020 17:33       2021
# 3                             8/31/2020 17:33       2021
# 4                             8/31/2020 17:33       2021
# 5                             7/30/2020 21:12       2021
# 6                             8/31/2020 17:33       2021
# 7                             8/31/2020 17:32       2021
# 8                             8/31/2020 17:33       2021
# 9                             8/31/2020 17:33       2021
# 10                            8/31/2020 17:33       2021
# 11                            8/31/2020 17:33       2021
# 12                            8/31/2020 17:33       2021
# 13                            8/31/2020 17:33       2021
# 14                            8/31/2020 17:33       2021
# 15                            8/31/2020 17:33       2021
# 16                            8/31/2020 17:33       2021
# 17                              8/1/2018 6:12       2021
# 18                            8/31/2020 17:33       2021
# 19                            8/31/2020 17:33       2021
# 20                            8/31/2020 17:33       2021
# 21                            8/31/2020 17:33       2021
# 22                            8/31/2020 17:33       2021
# 23                            8/31/2020 17:33       2021
# 24                            8/31/2020 17:33       2021
# 25                            8/31/2020 17:33       2021
# 26                            8/31/2020 17:33       2021
# 27                                        NaN       2021
# 28                            8/31/2020 17:33       2021
# 29                            8/31/2020 17:33       2021
# 30                            8/31/2020 17:34       2021
# 31                                        NaN       2021
# 32                                        NaN       2021
# 33                            8/31/2020 17:34       2021
# 34                                        NaN       2021
# 35                                        NaN       2021
# 36                            8/31/2020 17:34       2021
# 37                            8/31/2020 17:34       2021
# 38                                        NaN       2021
# 39                            8/31/2020 17:34       2021
#
#    DateInvestmentFirstSubmitted  DateofLastInvestmentDetailUpdate  \
# 0                6/30/2009 0:00                   8/31/2020 17:33
# 1                6/30/2009 0:00                   8/31/2020 17:33
# 2                6/30/2009 0:00                   8/31/2020 17:33
# 3                6/30/2009 0:00                   8/31/2020 17:33
# 4                6/30/2009 0:00                   8/31/2020 17:33
# 5                6/30/2009 0:00                   7/30/2020 21:12
# 6                6/30/2009 0:00                   8/31/2020 17:33
# 7                6/30/2009 0:00                   8/31/2020 17:32
# 8                6/30/2009 0:00                   8/31/2020 17:33
# 9                6/30/2009 0:00                   8/31/2020 17:33
# 10               6/30/2009 0:00                   8/31/2020 17:33
# 11               6/30/2009 0:00                   8/31/2020 17:33
# 12               6/30/2009 0:00                   8/31/2020 17:33
# 13               6/30/2009 0:00                   8/31/2020 17:33
# 14               6/30/2009 0:00                   8/31/2020 17:33
# 15               6/30/2009 0:00                   8/31/2020 17:33
# 16               6/30/2009 0:00                   8/31/2020 17:33
# 17               6/30/2009 0:00                   8/31/2020 17:32
# 18               6/30/2009 0:00                   8/31/2020 17:33
# 19               6/30/2009 0:00                   8/31/2020 17:33
# 20               6/30/2009 0:00                   8/31/2020 17:33
# 21               6/30/2009 0:00                   8/31/2020 17:33
# 22               3/17/2010 7:32                   8/31/2020 17:33
# 23              9/15/2011 11:45                   8/31/2020 17:33
# 24              9/28/2011 12:59                   8/31/2020 17:33
# 25              9/28/2011 13:00                   8/31/2020 17:33
# 26              9/19/2018 19:40                   8/31/2020 17:33
# 27              9/20/2018 19:51                   8/31/2020 17:33
# 28               6/30/2009 0:00                   8/31/2020 17:33
# 29               6/30/2009 0:00                   8/31/2020 17:33
# 30               6/30/2009 0:00                   8/31/2020 17:34
# 31               3/29/2013 8:07                   8/31/2020 17:34
# 32             11/14/2016 16:56                   8/31/2020 17:32
# 33              9/15/2015 11:23                   8/31/2020 17:34
# 34             11/14/2016 16:56                   8/31/2020 17:34
# 35             11/14/2016 16:56                   8/31/2020 17:34
# 36              9/19/2018 14:53                   8/31/2020 17:34
# 37              1/10/2018 17:29                   8/31/2020 17:34
# 38              9/18/2018 18:38                   8/31/2020 17:34
# 39              9/17/2019 19:43                   8/31/2020 17:34
#
#     InvestmentAutoSubmissionDate  InvestmentYears                    fileName
# 0                 6/30/2009 0:00               32  Business_Case-DHS-2021.csv
# 1                 6/30/2009 0:00               22  Business_Case-DHS-2021.csv
# 2                 6/30/2009 0:00               24  Business_Case-DHS-2021.csv
# 3                 6/30/2009 0:00               28  Business_Case-DHS-2021.csv
# 4                 6/30/2009 0:00               24  Business_Case-DHS-2021.csv
# 5                 6/30/2009 0:00               19  Business_Case-DHS-2021.csv
# 6                 6/30/2009 0:00               21  Business_Case-DHS-2021.csv
# 7                 6/30/2009 0:00               29  Business_Case-DHS-2021.csv
# 8                 6/30/2009 0:00               34  Business_Case-DHS-2021.csv
# 9                 6/30/2009 0:00               23  Business_Case-DHS-2021.csv
# 10                6/30/2009 0:00               25  Business_Case-DHS-2021.csv
# 11                6/30/2009 0:00               20  Business_Case-DHS-2021.csv
# 12                6/30/2009 0:00               25  Business_Case-DHS-2021.csv
# 13                6/30/2009 0:00               22  Business_Case-DHS-2021.csv
# 14                6/30/2009 0:00               40  Business_Case-DHS-2021.csv
# 15                6/30/2009 0:00               26  Business_Case-DHS-2021.csv
# 16                6/30/2009 0:00               17  Business_Case-DHS-2021.csv
# 17                6/30/2009 0:00               24  Business_Case-DHS-2021.csv
# 18                6/30/2009 0:00               17  Business_Case-DHS-2021.csv
# 19                6/30/2009 0:00               19  Business_Case-DHS-2021.csv
# 20                6/30/2009 0:00               39  Business_Case-DHS-2021.csv
# 21                6/30/2009 0:00               17  Business_Case-DHS-2021.csv
# 22                3/17/2010 7:32               22  Business_Case-DHS-2021.csv
# 23               9/15/2011 11:45               16  Business_Case-DHS-2021.csv
# 24               9/28/2011 12:59               18  Business_Case-DHS-2021.csv
# 25               9/28/2011 13:00               15  Business_Case-DHS-2021.csv
# 26               9/19/2018 19:40               21  Business_Case-DHS-2021.csv
# 27               9/20/2018 19:51               15  Business_Case-DHS-2021.csv
# 28                6/30/2009 0:00               27  Business_Case-DHS-2021.csv
# 29                6/30/2009 0:00               26  Business_Case-DHS-2021.csv
# 30                6/30/2009 0:00               18  Business_Case-DHS-2021.csv
# 31                3/29/2013 8:07               26  Business_Case-DHS-2021.csv
# 32              11/14/2016 16:56               14  Business_Case-DHS-2021.csv
# 33               9/15/2015 11:23                7  Business_Case-DHS-2021.csv
# 34              11/14/2016 16:56               14  Business_Case-DHS-2021.csv
# 35              11/14/2016 16:56                9  Business_Case-DHS-2021.csv
# 36               9/19/2018 14:53               15  Business_Case-DHS-2021.csv
# 37               1/10/2018 17:29               14  Business_Case-DHS-2021.csv
# 38               9/18/2018 18:38               11  Business_Case-DHS-2021.csv
# 39               9/17/2019 19:43               14  Business_Case-DHS-2021.csv
#
# [40 rows x 42 columns]
